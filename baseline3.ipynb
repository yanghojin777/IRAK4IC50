# %% [markdown]
# # IRAK4 IC50 prediction using XGBoost Regression

# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np
np.set_printoptions(threshold=np.inf, linewidth=99)
import os
import random

from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.linear_model import LinearRegression
import xgboost
from sklearn.metrics import mean_squared_error, r2_score

# %%
def pIC50_to_IC50(pic50_values):
    """Convert pIC50 values to IC50 (nM)."""
    return 10 ** (9 - pic50_values)

# %%
CFG = {
    'NBITS':2048,
    'SEED':42,
}

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(CFG['SEED']) # Seed 고정

# %% [markdown]
# ### DataLoad

# %%
# SMILES 데이터를 분자 지문으로 변환
def smiles_to_fingerprint(smiles):
    # 먼저 SMILES 데이터로 부터 구조식 데이터를 뽑고,
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        # 구조식으로부터 2048개의 0과 1로 이루어진 분자지문 데이터를 객체를 얻는다. 
        # 이 때, 1은 어떤 분자구조의 존재를 의미하며 0과 1의 개수는 nBits에 따라 달라진다. 
        # bitInfo 에 dictionary를 할당하면 어느 인덱스에 지문이 찍혔는지 알 수 있으며,
        # radius는 단일 맵핑 특성 생성에 사용되는 원자들의 반경,
        # nBits는 분자구조 맵핑을 위한 경로들의 고유조합수를 뜻한다.
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=CFG['NBITS'])
        # 객체를 배열로 변환해서 리턴
        return np.array(fp)
    else:
        # 구조식이 데이터가 없는 경우 2048개의 0을 리턴
        return np.zeros((CFG['NBITS'],))

# %%
# 학습 ChEMBL 데이터 로드
chembl_data = pd.read_csv('train.csv')  # 예시 파일 이름
chembl_data.head()
# Out:
#   Molecule ChEMBL ID Standard Type Standard Relation  Standard Value  \
# 0      CHEMBL4443947          IC50               '='           0.022
# 1      CHEMBL4556091          IC50               '='           0.026
# 2      CHEMBL4566431          IC50               '='           0.078
# 3      CHEMBL4545898          IC50               '='           0.081
# 4      CHEMBL4448950          IC50               '='           0.099
#
#   Standard Units  pChEMBL Value Assay ChEMBL ID Target ChEMBL ID  \
# 0             nM          10.66   CHEMBL4361896       CHEMBL3778
# 1             nM          10.59   CHEMBL4345131       CHEMBL3778
# 2             nM          10.11   CHEMBL4345131       CHEMBL3778
# 3             nM          10.09   CHEMBL4345131       CHEMBL3778
# 4             nM          10.00   CHEMBL4361896       CHEMBL3778
#
#                                   Target Name Target Organism     Target Type  \
# 0  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 1  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 2  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 3  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 4  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
#
#   Document ChEMBL ID  IC50_nM  pIC50  \
# 0      CHEMBL4359855    0.022  10.66
# 1      CHEMBL4342485    0.026  10.59
# 2      CHEMBL4342485    0.078  10.11
# 3      CHEMBL4342485    0.081  10.09
# 4      CHEMBL4359855    0.099  10.00
#
#                                               Smiles
# 0  CN[C@@H](C)C(=O)N[C@H](C(=O)N1C[C@@H](NC(=O)CC...
# 1  CC(C)(O)[C@H](F)CN1Cc2cc(NC(=O)c3cnn4cccnc34)c...
# 2  CC(C)(O)[C@H](F)CN1Cc2cc(NC(=O)c3cnn4cccnc34)c...
# 3  CC(C)(O)[C@H](F)CN1Cc2cc(NC(=O)c3cnn4cccnc34)c...
# 4  COc1cc2c(OC[C@@H]3CCC(=O)N3)ncc(C#CCCCCCCCCCCC...

# %% [markdown]
# ### Data Pre-processing

# %%
train = chembl_data[['Smiles', 'pIC50']]
train['Fingerprint'] = train['Smiles'].apply(smiles_to_fingerprint)

# 훈련데이터 X는 위 함수에서 얻은 분자지문 값, Y는 각각에 상응하는 pIC50 값으로 한다
train_x = np.stack(train['Fingerprint'].values)
train_y = train['pIC50'].values

# 학습 및 검증 데이터 분리
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size=0.3, random_state=42)
# Out:
# c:\Users\LG\anaconda3\envs\IRAK4IC50\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Train & Validation

# %%
# 의사결정나무류 최고의 모델로 학습
model = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75, colsample_bytree=1, max_depth=7)
model.fit(train_x, train_y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
# 의사결정나무류 최고의 모델로 학습
model = xgboost.XGBRegressor(n_estimators=300, max_depth=8, learning_rate=0.09, subsample=0.7, colsample_bytree=0.9)
model.fit(train_x, train_y)
# train r2: 0.9698
# val r2: 0.7256
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.9,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.09, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=8, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=300, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
model = xgboost.XGBRegressor(n_estimators=1000, learning_rate=0.09, verbosity=1, random_state=42, early_stopping_rounds=50,
                          gamma=0.1, importance_type='gain', reg_alpha=0, reg_lambda=1, min_child_weight=0, scale_pos_weight=1,
                          subsample=0.7, colsample_bytree=1, booster='gbtree', silent=1, max_depth=6)
model.fit(train_x, train_y, eval_set=[(val_x, val_y)])
# train r2: 0.9341
# val r2: 0.7278
# Out:
# [09:33:06] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-rmse:6.45528
# [1]	validation_0-rmse:5.88587
# [2]	validation_0-rmse:5.36936
# [3]	validation_0-rmse:4.89987
# [4]	validation_0-rmse:4.47396
# [5]	validation_0-rmse:4.08728
# [6]	validation_0-rmse:3.73065
# [7]	validation_0-rmse:3.40760
# [8]	validation_0-rmse:3.11786
# [9]	validation_0-rmse:2.85459
# [10]	validation_0-rmse:2.61281
# [11]	validation_0-rmse:2.39607
# [12]	validation_0-rmse:2.20091
# [13]	validation_0-rmse:2.02243
# [14]	validation_0-rmse:1.86526
# [15]	validation_0-rmse:1.72191
# [16]	validation_0-rmse:1.59495
# [17]	validation_0-rmse:1.47588
# [18]	validation_0-rmse:1.37211
# [19]	validation_0-rmse:1.27980
# [20]	validation_0-rmse:1.19623
# [21]	validation_0-rmse:1.12264
# [22]	validation_0-rmse:1.05875
# [23]	validation_0-rmse:1.00046
# [24]	validation_0-rmse:0.95194
# [25]	validation_0-rmse:0.90831
# [26]	validation_0-rmse:0.87013
# [27]	validation_0-rmse:0.83692
# [28]	validation_0-rmse:0.80932
# [29]	validation_0-rmse:0.78411
# [30]	validation_0-rmse:0.76215
# [31]	validation_0-rmse:0.74520
# [32]	validation_0-rmse:0.72735
# [33]	validation_0-rmse:0.71311
# [34]	validation_0-rmse:0.70063
# [35]	validation_0-rmse:0.69052
# [36]	validation_0-rmse:0.68252
# [37]	validation_0-rmse:0.67541
# [38]	validation_0-rmse:0.66727
# [39]	validation_0-rmse:0.66188
# [40]	validation_0-rmse:0.65666
# [41]	validation_0-rmse:0.65207
# [42]	validation_0-rmse:0.64725
# [43]	validation_0-rmse:0.64459
# [44]	validation_0-rmse:0.64141
# [45]	validation_0-rmse:0.63802
# [46]	validation_0-rmse:0.63568
# [47]	validation_0-rmse:0.63276
# [48]	validation_0-rmse:0.62943
# [49]	validation_0-rmse:0.62705
# [50]	validation_0-rmse:0.62690
# [51]	validation_0-rmse:0.62564
# [52]	validation_0-rmse:0.62428
# [53]	validation_0-rmse:0.62222
# [54]	validation_0-rmse:0.62031
# [55]	validation_0-rmse:0.61941
# [56]	validation_0-rmse:0.61812
# [57]	validation_0-rmse:0.61755
# [58]	validation_0-rmse:0.61659
# [59]	validation_0-rmse:0.61477
# [60]	validation_0-rmse:0.61476
# [61]	validation_0-rmse:0.61425
# [62]	validation_0-rmse:0.61485
# [63]	validation_0-rmse:0.61269
# [64]	validation_0-rmse:0.61198
# [65]	validation_0-rmse:0.61200
# [66]	validation_0-rmse:0.61163
# [67]	validation_0-rmse:0.61071
# [68]	validation_0-rmse:0.61053
# [69]	validation_0-rmse:0.60985
# [70]	validation_0-rmse:0.61049
# [71]	validation_0-rmse:0.61023
# [72]	validation_0-rmse:0.60922
# [73]	validation_0-rmse:0.60841
# [74]	validation_0-rmse:0.60829
# [75]	validation_0-rmse:0.60776
# [76]	validation_0-rmse:0.60761
# [77]	validation_0-rmse:0.60764
# [78]	validation_0-rmse:0.60704
# [79]	validation_0-rmse:0.60562
# [80]	validation_0-rmse:0.60469
# [81]	validation_0-rmse:0.60538
# [82]	validation_0-rmse:0.60484
# [83]	validation_0-rmse:0.60521
# [84]	validation_0-rmse:0.60443
# [85]	validation_0-rmse:0.60376
# [86]	validation_0-rmse:0.60321
# [87]	validation_0-rmse:0.60260
# [88]	validation_0-rmse:0.60231
# [89]	validation_0-rmse:0.60157
# [90]	validation_0-rmse:0.60071
# [91]	validation_0-rmse:0.59971
# [92]	validation_0-rmse:0.59881
# [93]	validation_0-rmse:0.59942
# [94]	validation_0-rmse:0.59995
# [95]	validation_0-rmse:0.59984
# [96]	validation_0-rmse:0.59969
# [97]	validation_0-rmse:0.59982
# [98]	validation_0-rmse:0.59978
# [99]	validation_0-rmse:0.59947
# [100]	validation_0-rmse:0.59914
# [101]	validation_0-rmse:0.59923
# [102]	validation_0-rmse:0.59844
# [103]	validation_0-rmse:0.59799
# [104]	validation_0-rmse:0.59854
# [105]	validation_0-rmse:0.59834
# [106]	validation_0-rmse:0.59799
# [107]	validation_0-rmse:0.59858
# [108]	validation_0-rmse:0.59797
# [109]	validation_0-rmse:0.59836
# [110]	validation_0-rmse:0.59870
# [111]	validation_0-rmse:0.59861
# [112]	validation_0-rmse:0.59733
# [113]	validation_0-rmse:0.59718
# [114]	validation_0-rmse:0.59524
# [115]	validation_0-rmse:0.59524
# [116]	validation_0-rmse:0.59547
# [117]	validation_0-rmse:0.59475
# [118]	validation_0-rmse:0.59398
# [119]	validation_0-rmse:0.59330
# [120]	validation_0-rmse:0.59297
# [121]	validation_0-rmse:0.59305
# [122]	validation_0-rmse:0.59204
# [123]	validation_0-rmse:0.59160
# [124]	validation_0-rmse:0.59160
# [125]	validation_0-rmse:0.59187
# [126]	validation_0-rmse:0.59224
# [127]	validation_0-rmse:0.59184
# [128]	validation_0-rmse:0.59166
# [129]	validation_0-rmse:0.59220
# [130]	validation_0-rmse:0.59265
# [131]	validation_0-rmse:0.59242
# [132]	validation_0-rmse:0.59249
# [133]	validation_0-rmse:0.59223
# [134]	validation_0-rmse:0.59148
# [135]	validation_0-rmse:0.59160
# [136]	validation_0-rmse:0.59170
# [137]	validation_0-rmse:0.59208
# [138]	validation_0-rmse:0.59202
# [139]	validation_0-rmse:0.59213
# [140]	validation_0-rmse:0.59181
# [141]	validation_0-rmse:0.59143
# [142]	validation_0-rmse:0.59041
# [143]	validation_0-rmse:0.58935
# [144]	validation_0-rmse:0.58916
# [145]	validation_0-rmse:0.58894
# [146]	validation_0-rmse:0.58819
# [147]	validation_0-rmse:0.58799
# [148]	validation_0-rmse:0.58775
# [149]	validation_0-rmse:0.58700
# [150]	validation_0-rmse:0.58697
# [151]	validation_0-rmse:0.58602
# [152]	validation_0-rmse:0.58535
# [153]	validation_0-rmse:0.58544
# [154]	validation_0-rmse:0.58549
# [155]	validation_0-rmse:0.58474
# [156]	validation_0-rmse:0.58502
# [157]	validation_0-rmse:0.58517
# [158]	validation_0-rmse:0.58512
# [159]	validation_0-rmse:0.58510
# [160]	validation_0-rmse:0.58465
# [161]	validation_0-rmse:0.58430
# [162]	validation_0-rmse:0.58463
# [163]	validation_0-rmse:0.58466
# [164]	validation_0-rmse:0.58490
# [165]	validation_0-rmse:0.58462
# [166]	validation_0-rmse:0.58522
# [167]	validation_0-rmse:0.58511
# [168]	validation_0-rmse:0.58527
# [169]	validation_0-rmse:0.58578
# [170]	validation_0-rmse:0.58550
# [171]	validation_0-rmse:0.58515
# [172]	validation_0-rmse:0.58471
# [173]	validation_0-rmse:0.58511
# [174]	validation_0-rmse:0.58491
# [175]	validation_0-rmse:0.58499
# [176]	validation_0-rmse:0.58503
# [177]	validation_0-rmse:0.58524
# [178]	validation_0-rmse:0.58457
# [179]	validation_0-rmse:0.58448
# [180]	validation_0-rmse:0.58405
# [181]	validation_0-rmse:0.58457
# [182]	validation_0-rmse:0.58408
# [183]	validation_0-rmse:0.58332
# [184]	validation_0-rmse:0.58306
# [185]	validation_0-rmse:0.58293
# [186]	validation_0-rmse:0.58285
# [187]	validation_0-rmse:0.58307
# [188]	validation_0-rmse:0.58277
# [189]	validation_0-rmse:0.58297
# [190]	validation_0-rmse:0.58292
# [191]	validation_0-rmse:0.58288
# [192]	validation_0-rmse:0.58338
# [193]	validation_0-rmse:0.58332
# [194]	validation_0-rmse:0.58270
# [195]	validation_0-rmse:0.58242
# [196]	validation_0-rmse:0.58261
# [197]	validation_0-rmse:0.58274
# [198]	validation_0-rmse:0.58288
# [199]	validation_0-rmse:0.58272
# [200]	validation_0-rmse:0.58266
# [201]	validation_0-rmse:0.58254
# [202]	validation_0-rmse:0.58239
# [203]	validation_0-rmse:0.58242
# [204]	validation_0-rmse:0.58230
# [205]	validation_0-rmse:0.58175
# [206]	validation_0-rmse:0.58179
# [207]	validation_0-rmse:0.58158
# [208]	validation_0-rmse:0.58130
# [209]	validation_0-rmse:0.58082
# [210]	validation_0-rmse:0.58057
# [211]	validation_0-rmse:0.58029
# [212]	validation_0-rmse:0.58058
# [213]	validation_0-rmse:0.58087
# [214]	validation_0-rmse:0.58124
# [215]	validation_0-rmse:0.58131
# [216]	validation_0-rmse:0.58122
# [217]	validation_0-rmse:0.58153
# [218]	validation_0-rmse:0.58182
# [219]	validation_0-rmse:0.58185
# [220]	validation_0-rmse:0.58163
# [221]	validation_0-rmse:0.58146
# [222]	validation_0-rmse:0.58132
# [223]	validation_0-rmse:0.58139
# [224]	validation_0-rmse:0.58065
# [225]	validation_0-rmse:0.58040
# [226]	validation_0-rmse:0.58025
# [227]	validation_0-rmse:0.58038
# [228]	validation_0-rmse:0.58035
# [229]	validation_0-rmse:0.57967
# [230]	validation_0-rmse:0.57937
# [231]	validation_0-rmse:0.57932
# [232]	validation_0-rmse:0.57943
# [233]	validation_0-rmse:0.57937
# [234]	validation_0-rmse:0.57938
# [235]	validation_0-rmse:0.57929
# [236]	validation_0-rmse:0.57932
# [237]	validation_0-rmse:0.57930
# [238]	validation_0-rmse:0.57925
# [239]	validation_0-rmse:0.57925
# [240]	validation_0-rmse:0.57910
# [241]	validation_0-rmse:0.57869
# [242]	validation_0-rmse:0.57918
# [243]	validation_0-rmse:0.57934
# [244]	validation_0-rmse:0.57938
# [245]	validation_0-rmse:0.57908
# [246]	validation_0-rmse:0.57947
# [247]	validation_0-rmse:0.57926
# [248]	validation_0-rmse:0.57942
# [249]	validation_0-rmse:0.57950
# [250]	validation_0-rmse:0.58068
# [251]	validation_0-rmse:0.58041
# [252]	validation_0-rmse:0.58007
# [253]	validation_0-rmse:0.57940
# [254]	validation_0-rmse:0.57939
# [255]	validation_0-rmse:0.57918
# [256]	validation_0-rmse:0.57933
# [257]	validation_0-rmse:0.57926
# [258]	validation_0-rmse:0.57937
# [259]	validation_0-rmse:0.57925
# [260]	validation_0-rmse:0.57923
# [261]	validation_0-rmse:0.57915
# [262]	validation_0-rmse:0.57943
# [263]	validation_0-rmse:0.57921
# [264]	validation_0-rmse:0.57960
# [265]	validation_0-rmse:0.57935
# [266]	validation_0-rmse:0.57916
# [267]	validation_0-rmse:0.57875
# [268]	validation_0-rmse:0.57885
# [269]	validation_0-rmse:0.57908
# [270]	validation_0-rmse:0.57963
# [271]	validation_0-rmse:0.57987
# [272]	validation_0-rmse:0.57994
# [273]	validation_0-rmse:0.58036
# [274]	validation_0-rmse:0.57996
# [275]	validation_0-rmse:0.58003
# [276]	validation_0-rmse:0.57974
# [277]	validation_0-rmse:0.57919
# [278]	validation_0-rmse:0.57980
# [279]	validation_0-rmse:0.57953
# [280]	validation_0-rmse:0.57938
# [281]	validation_0-rmse:0.57980
# [282]	validation_0-rmse:0.57973
# [283]	validation_0-rmse:0.57987
# [284]	validation_0-rmse:0.57990
# [285]	validation_0-rmse:0.57981
# [286]	validation_0-rmse:0.57984
# [287]	validation_0-rmse:0.57990
# [288]	validation_0-rmse:0.57997
# [289]	validation_0-rmse:0.57993
# [290]	validation_0-rmse:0.57986
# [291]	validation_0-rmse:0.58000
# [292]	validation_0-rmse:0.58002
# [293]	validation_0-rmse:0.57960
# [294]	validation_0-rmse:0.57981
# [295]	validation_0-rmse:0.57966
# [296]	validation_0-rmse:0.57991
# [297]	validation_0-rmse:0.58022
# [298]	validation_0-rmse:0.58027
# [299]	validation_0-rmse:0.58022
# [300]	validation_0-rmse:0.58030
# [301]	validation_0-rmse:0.58025
# [302]	validation_0-rmse:0.58030
# [303]	validation_0-rmse:0.58023
# [304]	validation_0-rmse:0.58019
# [305]	validation_0-rmse:0.58061
# [306]	validation_0-rmse:0.58041
# [307]	validation_0-rmse:0.58052
# [308]	validation_0-rmse:0.58040
# [309]	validation_0-rmse:0.58035
# [310]	validation_0-rmse:0.58049
# [311]	validation_0-rmse:0.58056
# [312]	validation_0-rmse:0.58058
# [313]	validation_0-rmse:0.58092
# [314]	validation_0-rmse:0.58106
# [315]	validation_0-rmse:0.58063
# [316]	validation_0-rmse:0.58072
# [317]	validation_0-rmse:0.58072
# [318]	validation_0-rmse:0.58090
# [319]	validation_0-rmse:0.58120
# [320]	validation_0-rmse:0.58129
# [321]	validation_0-rmse:0.58148
# [322]	validation_0-rmse:0.58140
# [323]	validation_0-rmse:0.58149
# [324]	validation_0-rmse:0.58166
# [325]	validation_0-rmse:0.58156
# [326]	validation_0-rmse:0.58151
# [327]	validation_0-rmse:0.58161
# [328]	validation_0-rmse:0.58192
# [329]	validation_0-rmse:0.58218
# [330]	validation_0-rmse:0.58200
# [331]	validation_0-rmse:0.58187
# [332]	validation_0-rmse:0.58184
# [333]	validation_0-rmse:0.58195
# [334]	validation_0-rmse:0.58213
# [335]	validation_0-rmse:0.58230
# [336]	validation_0-rmse:0.58232
# [337]	validation_0-rmse:0.58246
# [338]	validation_0-rmse:0.58257
# [339]	validation_0-rmse:0.58245
# [340]	validation_0-rmse:0.58208
# [341]	validation_0-rmse:0.58215
# [342]	validation_0-rmse:0.58228
# [343]	validation_0-rmse:0.58242
# [344]	validation_0-rmse:0.58276
# [345]	validation_0-rmse:0.58234
# [346]	validation_0-rmse:0.58203
# [347]	validation_0-rmse:0.58203
# [348]	validation_0-rmse:0.58194
# [349]	validation_0-rmse:0.58198
# [350]	validation_0-rmse:0.58140
# [351]	validation_0-rmse:0.58166
# [352]	validation_0-rmse:0.58167
# [353]	validation_0-rmse:0.58122
# [354]	validation_0-rmse:0.58118
# [355]	validation_0-rmse:0.58090
# [356]	validation_0-rmse:0.58048
# [357]	validation_0-rmse:0.58040
# [358]	validation_0-rmse:0.58059
# [359]	validation_0-rmse:0.58064
# [360]	validation_0-rmse:0.58046
# [361]	validation_0-rmse:0.58027
# [362]	validation_0-rmse:0.58025
# [363]	validation_0-rmse:0.58024
# [364]	validation_0-rmse:0.58001
# [365]	validation_0-rmse:0.58012
# [366]	validation_0-rmse:0.58037
# [367]	validation_0-rmse:0.58000
# [368]	validation_0-rmse:0.57966
# [369]	validation_0-rmse:0.57961
# [370]	validation_0-rmse:0.57964
# [371]	validation_0-rmse:0.57989
# [372]	validation_0-rmse:0.58012
# [373]	validation_0-rmse:0.57976
# [374]	validation_0-rmse:0.58030
# [375]	validation_0-rmse:0.58019
# [376]	validation_0-rmse:0.58052
# [377]	validation_0-rmse:0.58056
# [378]	validation_0-rmse:0.58031
# [379]	validation_0-rmse:0.58053
# [380]	validation_0-rmse:0.58064
# [381]	validation_0-rmse:0.58055
# [382]	validation_0-rmse:0.58050
# [383]	validation_0-rmse:0.58029
# [384]	validation_0-rmse:0.58028
# [385]	validation_0-rmse:0.58027
# [386]	validation_0-rmse:0.58040
# [387]	validation_0-rmse:0.58046
# [388]	validation_0-rmse:0.58052
# [389]	validation_0-rmse:0.58072
# [390]	validation_0-rmse:0.58085
# [391]	validation_0-rmse:0.58109
# [392]	validation_0-rmse:0.58124
# [393]	validation_0-rmse:0.58141
# [394]	validation_0-rmse:0.58135
# [395]	validation_0-rmse:0.58129
# [396]	validation_0-rmse:0.58118
# [397]	validation_0-rmse:0.58155
# [398]	validation_0-rmse:0.58167
# [399]	validation_0-rmse:0.58175
# [400]	validation_0-rmse:0.58150
# [401]	validation_0-rmse:0.58126
# [402]	validation_0-rmse:0.58125
# [403]	validation_0-rmse:0.58109
# [404]	validation_0-rmse:0.58116
# [405]	validation_0-rmse:0.58143
# [406]	validation_0-rmse:0.58161
# [407]	validation_0-rmse:0.58161
# [408]	validation_0-rmse:0.58195
# [409]	validation_0-rmse:0.58204
# [410]	validation_0-rmse:0.58226
# [411]	validation_0-rmse:0.58252
# [412]	validation_0-rmse:0.58277
# [413]	validation_0-rmse:0.58295
# [414]	validation_0-rmse:0.58292
# [415]	validation_0-rmse:0.58262
# [416]	validation_0-rmse:0.58254
# [417]	validation_0-rmse:0.58253
# [418]	validation_0-rmse:0.58255
# [419]	validation_0-rmse:0.58251
# [420]	validation_0-rmse:0.58271
# [421]	validation_0-rmse:0.58295
# [422]	validation_0-rmse:0.58281
# [423]	validation_0-rmse:0.58270
# [424]	validation_0-rmse:0.58205
# [425]	validation_0-rmse:0.58198
# [426]	validation_0-rmse:0.58209
# [427]	validation_0-rmse:0.58205
# [428]	validation_0-rmse:0.58237
# [429]	validation_0-rmse:0.58226
# [430]	validation_0-rmse:0.58230
# [431]	validation_0-rmse:0.58281
# [432]	validation_0-rmse:0.58282
# [433]	validation_0-rmse:0.58314
# [434]	validation_0-rmse:0.58339
# [435]	validation_0-rmse:0.58335
# [436]	validation_0-rmse:0.58332
# [437]	validation_0-rmse:0.58352
# [438]	validation_0-rmse:0.58352
# [439]	validation_0-rmse:0.58354
# [440]	validation_0-rmse:0.58375
# [441]	validation_0-rmse:0.58362
# [442]	validation_0-rmse:0.58361
# [443]	validation_0-rmse:0.58351
# [444]	validation_0-rmse:0.58344
# [445]	validation_0-rmse:0.58340
# [446]	validation_0-rmse:0.58335
# [447]	validation_0-rmse:0.58342
# [448]	validation_0-rmse:0.58314
# [449]	validation_0-rmse:0.58313
# [450]	validation_0-rmse:0.58300
# [451]	validation_0-rmse:0.58288
# [452]	validation_0-rmse:0.58288
# [453]	validation_0-rmse:0.58280
# [454]	validation_0-rmse:0.58287
# [455]	validation_0-rmse:0.58285
# [456]	validation_0-rmse:0.58265
# [457]	validation_0-rmse:0.58279
# [458]	validation_0-rmse:0.58271
# [459]	validation_0-rmse:0.58258
# [460]	validation_0-rmse:0.58285
# [461]	validation_0-rmse:0.58331
# [462]	validation_0-rmse:0.58348
# [463]	validation_0-rmse:0.58359
# [464]	validation_0-rmse:0.58365
# [465]	validation_0-rmse:0.58394
# [466]	validation_0-rmse:0.58402
# [467]	validation_0-rmse:0.58396
# [468]	validation_0-rmse:0.58417
# [469]	validation_0-rmse:0.58435
# [470]	validation_0-rmse:0.58419
# [471]	validation_0-rmse:0.58418
# [472]	validation_0-rmse:0.58427
# [473]	validation_0-rmse:0.58429
# [474]	validation_0-rmse:0.58442
# [475]	validation_0-rmse:0.58418
# [476]	validation_0-rmse:0.58370
# [477]	validation_0-rmse:0.58374
# [478]	validation_0-rmse:0.58334
# [479]	validation_0-rmse:0.58339
# [480]	validation_0-rmse:0.58343
# [481]	validation_0-rmse:0.58361
# [482]	validation_0-rmse:0.58337
# [483]	validation_0-rmse:0.58330
# [484]	validation_0-rmse:0.58341
# [485]	validation_0-rmse:0.58358
# [486]	validation_0-rmse:0.58347
# [487]	validation_0-rmse:0.58353
# [488]	validation_0-rmse:0.58385
# [489]	validation_0-rmse:0.58348
# [490]	validation_0-rmse:0.58378
# [491]	validation_0-rmse:0.58425
# [492]	validation_0-rmse:0.58415
# [493]	validation_0-rmse:0.58425
# [494]	validation_0-rmse:0.58444
# [495]	validation_0-rmse:0.58443
# [496]	validation_0-rmse:0.58437
# [497]	validation_0-rmse:0.58418
# [498]	validation_0-rmse:0.58431
# [499]	validation_0-rmse:0.58473
# [500]	validation_0-rmse:0.58471
# [501]	validation_0-rmse:0.58501
# [502]	validation_0-rmse:0.58479
# [503]	validation_0-rmse:0.58474
# [504]	validation_0-rmse:0.58459
# [505]	validation_0-rmse:0.58426
# [506]	validation_0-rmse:0.58380
# [507]	validation_0-rmse:0.58371
# [508]	validation_0-rmse:0.58362
# [509]	validation_0-rmse:0.58388
# [510]	validation_0-rmse:0.58393
# [511]	validation_0-rmse:0.58385
# [512]	validation_0-rmse:0.58395
# [513]	validation_0-rmse:0.58391
# [514]	validation_0-rmse:0.58387
# [515]	validation_0-rmse:0.58372
# [516]	validation_0-rmse:0.58378
# [517]	validation_0-rmse:0.58376
# [518]	validation_0-rmse:0.58351
# [519]	validation_0-rmse:0.58346
# [520]	validation_0-rmse:0.58369
# [521]	validation_0-rmse:0.58324
# [522]	validation_0-rmse:0.58352
# [523]	validation_0-rmse:0.58382
# [524]	validation_0-rmse:0.58371
# [525]	validation_0-rmse:0.58382
# [526]	validation_0-rmse:0.58378
# [527]	validation_0-rmse:0.58394
# [528]	validation_0-rmse:0.58409
# [529]	validation_0-rmse:0.58412
# [530]	validation_0-rmse:0.58410
# [531]	validation_0-rmse:0.58424
# [532]	validation_0-rmse:0.58438
# [533]	validation_0-rmse:0.58421
# [534]	validation_0-rmse:0.58407
# [535]	validation_0-rmse:0.58401
# [536]	validation_0-rmse:0.58450
# [537]	validation_0-rmse:0.58441
# [538]	validation_0-rmse:0.58452
# [539]	validation_0-rmse:0.58448
# [540]	validation_0-rmse:0.58449
# [541]	validation_0-rmse:0.58443
# [542]	validation_0-rmse:0.58444
# [543]	validation_0-rmse:0.58460
# [544]	validation_0-rmse:0.58454
# [545]	validation_0-rmse:0.58463
# [546]	validation_0-rmse:0.58459
# [547]	validation_0-rmse:0.58487
# [548]	validation_0-rmse:0.58465
# [549]	validation_0-rmse:0.58459
# [550]	validation_0-rmse:0.58465
# [551]	validation_0-rmse:0.58440
# [552]	validation_0-rmse:0.58453
# [553]	validation_0-rmse:0.58477
# [554]	validation_0-rmse:0.58448
# [555]	validation_0-rmse:0.58428
# [556]	validation_0-rmse:0.58419
# [557]	validation_0-rmse:0.58437
# [558]	validation_0-rmse:0.58437
# [559]	validation_0-rmse:0.58437
# [560]	validation_0-rmse:0.58471
# [561]	validation_0-rmse:0.58470
# [562]	validation_0-rmse:0.58469
# [563]	validation_0-rmse:0.58448
# [564]	validation_0-rmse:0.58451
# [565]	validation_0-rmse:0.58443
# [566]	validation_0-rmse:0.58439
# [567]	validation_0-rmse:0.58432
# [568]	validation_0-rmse:0.58422
# [569]	validation_0-rmse:0.58425
# [570]	validation_0-rmse:0.58406
# [571]	validation_0-rmse:0.58402
# [572]	validation_0-rmse:0.58428
# [573]	validation_0-rmse:0.58441
# [574]	validation_0-rmse:0.58445
# [575]	validation_0-rmse:0.58459
# [576]	validation_0-rmse:0.58451
# [577]	validation_0-rmse:0.58435
# [578]	validation_0-rmse:0.58421
# [579]	validation_0-rmse:0.58415
# [580]	validation_0-rmse:0.58405
# [581]	validation_0-rmse:0.58434
# [582]	validation_0-rmse:0.58405
# [583]	validation_0-rmse:0.58420
# [584]	validation_0-rmse:0.58450
# [585]	validation_0-rmse:0.58455
# [586]	validation_0-rmse:0.58458
# [587]	validation_0-rmse:0.58451
# [588]	validation_0-rmse:0.58462
# [589]	validation_0-rmse:0.58446
# [590]	validation_0-rmse:0.58439
# [591]	validation_0-rmse:0.58419
# [592]	validation_0-rmse:0.58412
# [593]	validation_0-rmse:0.58407
# [594]	validation_0-rmse:0.58433
# [595]	validation_0-rmse:0.58429
# [596]	validation_0-rmse:0.58434
# [597]	validation_0-rmse:0.58421
# [598]	validation_0-rmse:0.58428
# [599]	validation_0-rmse:0.58408
# [600]	validation_0-rmse:0.58380
# [601]	validation_0-rmse:0.58380
# [602]	validation_0-rmse:0.58361
# [603]	validation_0-rmse:0.58375
# [604]	validation_0-rmse:0.58369
# [605]	validation_0-rmse:0.58365
# [606]	validation_0-rmse:0.58367
# [607]	validation_0-rmse:0.58364
# [608]	validation_0-rmse:0.58362
# [609]	validation_0-rmse:0.58373
# [610]	validation_0-rmse:0.58376
# [611]	validation_0-rmse:0.58368
# [612]	validation_0-rmse:0.58370
# [613]	validation_0-rmse:0.58346
# [614]	validation_0-rmse:0.58320
# [615]	validation_0-rmse:0.58334
# [616]	validation_0-rmse:0.58322
# [617]	validation_0-rmse:0.58327
# [618]	validation_0-rmse:0.58320
# [619]	validation_0-rmse:0.58319
# [620]	validation_0-rmse:0.58293
# [621]	validation_0-rmse:0.58331
# [622]	validation_0-rmse:0.58327
# [623]	validation_0-rmse:0.58359
# [624]	validation_0-rmse:0.58399
# [625]	validation_0-rmse:0.58424
# [626]	validation_0-rmse:0.58427
# [627]	validation_0-rmse:0.58395
# [628]	validation_0-rmse:0.58394
# [629]	validation_0-rmse:0.58383
# [630]	validation_0-rmse:0.58390
# [631]	validation_0-rmse:0.58395
# [632]	validation_0-rmse:0.58402
# [633]	validation_0-rmse:0.58413
# [634]	validation_0-rmse:0.58402
# [635]	validation_0-rmse:0.58387
# [636]	validation_0-rmse:0.58397
# [637]	validation_0-rmse:0.58383
# [638]	validation_0-rmse:0.58382
# [639]	validation_0-rmse:0.58378
# [640]	validation_0-rmse:0.58386
# [641]	validation_0-rmse:0.58413
# [642]	validation_0-rmse:0.58398
# [643]	validation_0-rmse:0.58421
# [644]	validation_0-rmse:0.58396
# [645]	validation_0-rmse:0.58395
# [646]	validation_0-rmse:0.58442
# [647]	validation_0-rmse:0.58446
# [648]	validation_0-rmse:0.58442
# [649]	validation_0-rmse:0.58436
# [650]	validation_0-rmse:0.58446
# [651]	validation_0-rmse:0.58437
# [652]	validation_0-rmse:0.58453
# [653]	validation_0-rmse:0.58444
# [654]	validation_0-rmse:0.58416
# [655]	validation_0-rmse:0.58418
# [656]	validation_0-rmse:0.58408
# [657]	validation_0-rmse:0.58438
# [658]	validation_0-rmse:0.58435
# [659]	validation_0-rmse:0.58454
# [660]	validation_0-rmse:0.58490
# [661]	validation_0-rmse:0.58486
# [662]	validation_0-rmse:0.58502
# [663]	validation_0-rmse:0.58505
# [664]	validation_0-rmse:0.58518
# [665]	validation_0-rmse:0.58523
# [666]	validation_0-rmse:0.58522
# [667]	validation_0-rmse:0.58493
# [668]	validation_0-rmse:0.58480
# [669]	validation_0-rmse:0.58447
# [670]	validation_0-rmse:0.58442
# [671]	validation_0-rmse:0.58428
# [672]	validation_0-rmse:0.58420
# [673]	validation_0-rmse:0.58417
# [674]	validation_0-rmse:0.58433
# [675]	validation_0-rmse:0.58435
# [676]	validation_0-rmse:0.58439
# [677]	validation_0-rmse:0.58427
# [678]	validation_0-rmse:0.58452
# [679]	validation_0-rmse:0.58462
# [680]	validation_0-rmse:0.58471
# [681]	validation_0-rmse:0.58451
# [682]	validation_0-rmse:0.58432
# [683]	validation_0-rmse:0.58439
# [684]	validation_0-rmse:0.58438
# [685]	validation_0-rmse:0.58427
# [686]	validation_0-rmse:0.58411
# [687]	validation_0-rmse:0.58433
# [688]	validation_0-rmse:0.58406
# [689]	validation_0-rmse:0.58408
# [690]	validation_0-rmse:0.58436
# [691]	validation_0-rmse:0.58404
# [692]	validation_0-rmse:0.58418
# [693]	validation_0-rmse:0.58437
# [694]	validation_0-rmse:0.58439
# [695]	validation_0-rmse:0.58427
# [696]	validation_0-rmse:0.58432
# [697]	validation_0-rmse:0.58478
# [698]	validation_0-rmse:0.58474
# [699]	validation_0-rmse:0.58470
# [700]	validation_0-rmse:0.58468
# [701]	validation_0-rmse:0.58480
# [702]	validation_0-rmse:0.58475
# [703]	validation_0-rmse:0.58469
# [704]	validation_0-rmse:0.58430
# [705]	validation_0-rmse:0.58430
# [706]	validation_0-rmse:0.58410
# [707]	validation_0-rmse:0.58438
# [708]	validation_0-rmse:0.58420
# [709]	validation_0-rmse:0.58405
# [710]	validation_0-rmse:0.58402
# [711]	validation_0-rmse:0.58400
# [712]	validation_0-rmse:0.58406
# [713]	validation_0-rmse:0.58402
# [714]	validation_0-rmse:0.58423
# [715]	validation_0-rmse:0.58411
# [716]	validation_0-rmse:0.58417
# [717]	validation_0-rmse:0.58406
# [718]	validation_0-rmse:0.58404
# [719]	validation_0-rmse:0.58413
# [720]	validation_0-rmse:0.58405
# [721]	validation_0-rmse:0.58402
# [722]	validation_0-rmse:0.58436
# [723]	validation_0-rmse:0.58450
# [724]	validation_0-rmse:0.58458
# [725]	validation_0-rmse:0.58445
# [726]	validation_0-rmse:0.58438
# [727]	validation_0-rmse:0.58447
# [728]	validation_0-rmse:0.58464
# [729]	validation_0-rmse:0.58482
# [730]	validation_0-rmse:0.58495
# [731]	validation_0-rmse:0.58489
# [732]	validation_0-rmse:0.58488
# [733]	validation_0-rmse:0.58481
# [734]	validation_0-rmse:0.58513
# [735]	validation_0-rmse:0.58544
# [736]	validation_0-rmse:0.58543
# [737]	validation_0-rmse:0.58527
# [738]	validation_0-rmse:0.58495
# [739]	validation_0-rmse:0.58509
# [740]	validation_0-rmse:0.58495
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=500, enable_categorical=False,
#              eval_metric=None, gamma=0.1, gpu_id=-1, grow_policy='depthwise',
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.09, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=0,
#              missing=nan, monotone_constraints='()', n_estimators=1000,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=42,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
# train 데이터로부터의 학습 모델 평가

# pIC50 값 예측
train_y_pred = model.predict(train_x)
# 정답 IC50 값과 예측된 IC50 값을 비교하여 평균 제곱 오차값 산출 
mse = mean_squared_error(pIC50_to_IC50(train_y), pIC50_to_IC50(train_y_pred))
# 평균 제곱 오차값을 평균제곱근 오차값으로 변환
rmse = np.sqrt(mse)
print(f'RMSE: {rmse}')

# # 훈련데이터와 그 예측값(pIC50)과의 상관관계(결정계수) 
print("r2_score:", r2_score(train_y, train_y_pred))
# Out:
# RMSE: 1627.4641846534028
# r2_score: 0.9340548645979841

# %%
# Validation 데이터로부터의 학습 모델 평가

# pIC50 값 예측
val_y_pred = model.predict(val_x)
# 정답 IC50 값과 예측된 IC50 값을 비교하여 평균 제곱 오차값 산출 
mse = mean_squared_error(pIC50_to_IC50(val_y), pIC50_to_IC50(val_y_pred))
# 평균 제곱 오차값을 평균제곱근 오차값으로 변환
rmse = np.sqrt(mse)
print(f'RMSE: {rmse}')

# val 데이터로 결정계수 확인
print("r2_score:", r2_score(val_y, val_y_pred))
# Out:
# RMSE: 2171.3986061769915
# r2_score: 0.7278241335885223

# %% [markdown]
# ### Inference

# %%
# test 데이터로부터의 학습 모델 평가
test = pd.read_csv('./test.csv')
test['Fingerprint'] = test['Smiles'].apply(smiles_to_fingerprint)

test_x = np.stack(test['Fingerprint'].values)

# pIC50 값 예측
test_y_pred = model.predict(test_x)

np.set_printoptions(threshold=np.inf, linewidth=np.inf)
pIC50_to_IC50(test_y_pred)[:10]
# Out:
# array([181.96170602,  31.64219967,  10.78052721,  21.3766674 ,  25.31278906,   9.00616709,  26.86828832,  25.04378692,  35.17156285, 180.01139604])

# %% [markdown]
# ### Submission

# %%
submit = pd.read_csv('./sample_submission.csv')
submit['IC50_nM'] = pIC50_to_IC50(test_y_pred)
submit.head()
# Out:
#          ID     IC50_nM
# 0  TEST_000  181.961706
# 1  TEST_001   31.642200
# 2  TEST_002   10.780527
# 3  TEST_003   21.376667
# 4  TEST_004   25.312789

# %%
submit.to_csv('./baseline_submit.csv', index=False)
